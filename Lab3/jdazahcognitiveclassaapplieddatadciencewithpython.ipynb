# %% [markdown]
# https://www.linkedin.com/in/johan-d-4103a5121/

# %% [markdown]
# ![jdazahcognitiveclassaapplieddatadciencewithpython.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# https://www.linkedin.com/feed/update/urn:li:activity:6777766266934456320/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.linkedin.com/feed/update/urn:li:activity:6778402868199264256/

# %% [markdown]
# ![image.png](data:image/png;base64,...)
